# %%
import os
from PIL import Image
import numpy as np

annotation_folder = 'C:/Users/takatsuto/MLBook/data/Mushrooms/edible_anno_otsu'  # アノテーション画像のフォルダパス
image_folder = 'C:/Users/takatsuto/MLBook/data/Mushrooms/edible'            # 元画像のフォルダパス
output_folder = 'C:/Users/takatsuto/MLBook/data/Mushrooms/edible_result3_annosum'     # 出力画像の保存先フォルダ
threshold = 1000  

def process_images(annotation_folder, image_folder, output_folder, threshold):
    # アノテーション画像と元画像が格納されているフォルダを探索
    annotation_files = os.listdir(annotation_folder)

    for filename in annotation_files:
        # アノテーション画像と元画像のファイルパス
        annotation_path = os.path.join(annotation_folder, filename)
        image_path = os.path.join(image_folder, filename)

        # アノテーション画像と元画像を読み込む
        annotation_img = Image.open(annotation_path).convert('L')  # グレースケール画像
        original_img = Image.open(image_path)

        # アノテーション画像をNumPy配列に変換
        annotation_array = np.array(annotation_img)

        # アノテーション画像の値を0~1に正規化（255で割る）
        normalized_annotation_array = annotation_array / 255.0

        # 各画素値の合計を計算
        annotation_sum = np.sum(normalized_annotation_array)

        # 元画像をNumPy配列に変換
        original_array = np.array(original_img)

        # 合計が閾値より大きい場合は掛け算して出力、閾値より小さい場合は元画像をそのまま保存
        if annotation_sum >= threshold:
            # 元画像にアノテーション画像の値を掛け算して調整（強さを変更）
            result_array = original_array * normalized_annotation_array[..., np.newaxis]
            # 結果をPIL画像に戻す
            result_img = Image.fromarray(np.uint8(result_array))
            result_img.save(os.path.join(output_folder, filename))  # 処理結果を保存
            print(f"Processed and saved: {filename} (with annotation)")
        else:
            # アノテーション画像の合計が閾値より小さい場合、そのまま元画像を保存
            original_img.save(os.path.join(output_folder, filename))  # 元画像をそのまま保存
            print(f"Saved original image: {filename} (without annotation)")

        # 出力先フォルダがなければ作成
        os.makedirs(output_folder, exist_ok=True)

# 画像処理を実行
process_images(annotation_folder, image_folder, output_folder, threshold)
# Out:
# Processed and saved: Agaricus_arvensis0.png (with annotation)
# Processed and saved: Agaricus_arvensis1.png (with annotation)
# Processed and saved: Agaricus_arvensis10.png (with annotation)
# Saved original image: Agaricus_arvensis11.png (without annotation)
# Processed and saved: Agaricus_arvensis12.png (with annotation)
# Processed and saved: Agaricus_arvensis13.png (with annotation)
# Processed and saved: Agaricus_arvensis14.png (with annotation)
# Processed and saved: Agaricus_arvensis15.png (with annotation)
# Processed and saved: Agaricus_arvensis16.png (with annotation)
# Processed and saved: Agaricus_arvensis17.png (with annotation)
# Processed and saved: Agaricus_arvensis18.png (with annotation)
# Processed and saved: Agaricus_arvensis19.png (with annotation)
# Processed and saved: Agaricus_arvensis2.png (with annotation)
# Saved original image: Agaricus_arvensis21.png (without annotation)
# Processed and saved: Agaricus_arvensis22.png (with annotation)
# Processed and saved: Agaricus_arvensis23.png (with annotation)
# Processed and saved: Agaricus_arvensis24.png (with annotation)
# Processed and saved: Agaricus_arvensis25.png (with annotation)
# Processed and saved: Agaricus_arvensis26.png (with annotation)
# Processed and saved: Agaricus_arvensis27.png (with annotation)
# Processed and saved: Agaricus_arvensis28.png (with annotation)
# Processed and saved: Agaricus_arvensis29.png (with annotation)
# Processed and saved: Agaricus_arvensis3.png (with annotation)
# Processed and saved: Agaricus_arvensis30.png (with annotation)
# Processed and saved: Agaricus_arvensis31.png (with annotation)
# Processed and saved: Agaricus_arvensis32.png (with annotation)
# Processed and saved: Agaricus_arvensis33.png (with annotation)
# Processed and saved: Agaricus_arvensis34.png (with annotation)
# Processed and saved: Agaricus_arvensis35.png (with annotation)
# Processed and saved: Agaricus_arvensis36.png (with annotation)
# Processed and saved: Agaricus_arvensis37.png (with annotation)
# Processed and saved: Agaricus_arvensis38.png (with annotation)
# Processed and saved: Agaricus_arvensis39.png (with annotation)
# Processed and saved: Agaricus_arvensis40.png (with annotation)
# Processed and saved: Agaricus_arvensis41.png (with annotation)
# Processed and saved: Agaricus_arvensis42.png (with annotation)
# Processed and saved: Agaricus_arvensis6.png (with annotation)
# Processed and saved: Agaricus_arvensis8.png (with annotation)
# Processed and saved: Agaricus_arvensis9.png (with annotation)
# Processed and saved: Agaricus_bisporus1.png (with annotation)
# Saved original image: Agaricus_bisporus12.png (without annotation)
# Processed and saved: Agaricus_bisporus15.png (with annotation)
# Processed and saved: Agaricus_bisporus18.png (with annotation)
# Processed and saved: Agaricus_bisporus20.png (with annotation)
# Processed and saved: Agaricus_bisporus23.png (with annotation)
# Processed and saved: Agaricus_bisporus24.png (with annotation)
# Processed and saved: Agaricus_bisporus25.png (with annotation)
# Processed and saved: Agaricus_bisporus28.png (with annotation)
# Processed and saved: Agaricus_bisporus29.png (with annotation)
# Processed and saved: Agaricus_bisporus3.png (with annotation)
# Processed and saved: Agaricus_bisporus30.png (with annotation)
# Processed and saved: Agaricus_bisporus31.png (with annotation)
# Processed and saved: Agaricus_bisporus32.png (with annotation)
# Processed and saved: Agaricus_bisporus33.png (with annotation)
# Processed and saved: Agaricus_bisporus34.png (with annotation)
# Processed and saved: Agaricus_bisporus35.png (with annotation)
# Processed and saved: Agaricus_bisporus36.png (with annotation)
# Processed and saved: Agaricus_bisporus37.png (with annotation)
# Processed and saved: Agaricus_bisporus38.png (with annotation)
# Processed and saved: Agaricus_bisporus39.png (with annotation)
# Processed and saved: Agaricus_bisporus4.png (with annotation)
# Processed and saved: Agaricus_bisporus40.png (with annotation)
# Processed and saved: Agaricus_bisporus42.png (with annotation)
# Processed and saved: Agaricus_bisporus43.png (with annotation)
# Processed and saved: Agaricus_bisporus44.png (with annotation)
# Processed and saved: Agaricus_bisporus45.png (with annotation)
# Processed and saved: Agaricus_bisporus46.png (with annotation)
# Processed and saved: Agaricus_bisporus47.png (with annotation)
# Processed and saved: Agaricus_bisporus48.png (with annotation)
# Processed and saved: Agaricus_bisporus49.png (with annotation)
# Processed and saved: Agaricus_bisporus5.png (with annotation)
# Processed and saved: Agaricus_bisporus50.png (with annotation)
# Processed and saved: Agaricus_bisporus51.png (with annotation)
# Processed and saved: Agaricus_bisporus52.png (with annotation)
# Processed and saved: Agaricus_bisporus53.png (with annotation)
# Processed and saved: Agaricus_bisporus54.png (with annotation)
# Processed and saved: Agaricus_bisporus56.png (with annotation)
# Processed and saved: Agaricus_bisporus57.png (with annotation)
# Processed and saved: Agaricus_bisporus58.png (with annotation)
# Processed and saved: Agaricus_bisporus59.png (with annotation)
# Processed and saved: Agaricus_bisporus60.png (with annotation)
# Processed and saved: Agaricus_bisporus61.png (with annotation)
# Processed and saved: Agaricus_bisporus62.png (with annotation)
# Processed and saved: Agaricus_bisporus63.png (with annotation)
# Processed and saved: Agaricus_bisporus64.png (with annotation)
# Processed and saved: Agaricus_bisporus65.png (with annotation)
# Saved original image: Agaricus_bisporus66.png (without annotation)
# Processed and saved: Agaricus_bisporus67.png (with annotation)
# Processed and saved: Agaricus_bisporus68.png (with annotation)
# Processed and saved: Agaricus_bisporus69.png (with annotation)
# Processed and saved: Agaricus_bisporus70.png (with annotation)
# Processed and saved: Agaricus_bisporus9.png (with annotation)
# Processed and saved: Agaricus_silvaticus0.png (with annotation)
# Processed and saved: Agaricus_silvaticus1.png (with annotation)
# Processed and saved: Agaricus_silvaticus10.png (with annotation)
# Processed and saved: Agaricus_silvaticus11.png (with annotation)
# Processed and saved: Agaricus_silvaticus12.png (with annotation)
# Processed and saved: Agaricus_silvaticus13.png (with annotation)
# Processed and saved: Agaricus_silvaticus14.png (with annotation)
# Processed and saved: Agaricus_silvaticus15.png (with annotation)
# Processed and saved: Agaricus_silvaticus16.png (with annotation)
# Processed and saved: Agaricus_silvaticus17.png (with annotation)
# Processed and saved: Agaricus_silvaticus18.png (with annotation)
# Processed and saved: Agaricus_silvaticus19.png (with annotation)
# Processed and saved: Agaricus_silvaticus2.png (with annotation)
# Processed and saved: Agaricus_silvaticus20.png (with annotation)
# Processed and saved: Agaricus_silvaticus21.png (with annotation)
# Processed and saved: Agaricus_silvaticus22.png (with annotation)
# Processed and saved: Agaricus_silvaticus23.png (with annotation)
# Processed and saved: Agaricus_silvaticus24.png (with annotation)
# Processed and saved: Agaricus_silvaticus25.png (with annotation)
# Processed and saved: Agaricus_silvaticus26.png (with annotation)
# Processed and saved: Agaricus_silvaticus27.png (with annotation)
# Processed and saved: Agaricus_silvaticus28.png (with annotation)
# Processed and saved: Agaricus_silvaticus29.png (with annotation)
# Processed and saved: Agaricus_silvaticus3.png (with annotation)
# Processed and saved: Agaricus_silvaticus30.png (with annotation)
# Processed and saved: Agaricus_silvaticus4.png (with annotation)
# Processed and saved: Agaricus_silvaticus5.png (with annotation)
# Processed and saved: Agaricus_silvaticus6.png (with annotation)
# Processed and saved: Agaricus_silvaticus7.png (with annotation)
# Processed and saved: Agaricus_silvaticus8.png (with annotation)
# Processed and saved: Agaricus_silvaticus9.png (with annotation)
# Processed and saved: Aleuria_aurantia0.png (with annotation)
# Processed and saved: Aleuria_aurantia1.png (with annotation)
# Processed and saved: Aleuria_aurantia10.png (with annotation)
# Processed and saved: Aleuria_aurantia11.png (with annotation)
# Processed and saved: Aleuria_aurantia12.png (with annotation)
# Processed and saved: Aleuria_aurantia13.png (with annotation)
# Processed and saved: Aleuria_aurantia14.png (with annotation)
# Processed and saved: Aleuria_aurantia15.png (with annotation)
# Processed and saved: Aleuria_aurantia16.png (with annotation)
# Processed and saved: Aleuria_aurantia17.png (with annotation)
# Processed and saved: Aleuria_aurantia18.png (with annotation)
# Processed and saved: Aleuria_aurantia19.png (with annotation)
# Processed and saved: Aleuria_aurantia2.png (with annotation)
# Processed and saved: Aleuria_aurantia20.png (with annotation)
# Processed and saved: Aleuria_aurantia21.png (with annotation)
# Processed and saved: Aleuria_aurantia22.png (with annotation)
# Processed and saved: Aleuria_aurantia23.png (with annotation)
# Processed and saved: Aleuria_aurantia24.png (with annotation)
# Processed and saved: Aleuria_aurantia25.png (with annotation)
# Processed and saved: Aleuria_aurantia26.png (with annotation)
# Processed and saved: Aleuria_aurantia27.png (with annotation)
# Processed and saved: Aleuria_aurantia3.png (with annotation)
# Processed and saved: Aleuria_aurantia4.png (with annotation)
# Processed and saved: Aleuria_aurantia5.png (with annotation)
# Processed and saved: Aleuria_aurantia6.png (with annotation)
# Processed and saved: Aleuria_aurantia7.png (with annotation)
# Processed and saved: Aleuria_aurantia8.png (with annotation)
# Processed and saved: Aleuria_aurantia9.png (with annotation)
# Processed and saved: Amanita_caesarea0.png (with annotation)
# Processed and saved: Amanita_caesarea10.png (with annotation)
# Processed and saved: Amanita_caesarea11.png (with annotation)
# Processed and saved: Amanita_caesarea12.png (with annotation)
# Processed and saved: Amanita_caesarea13.png (with annotation)
# Processed and saved: Amanita_caesarea14.png (with annotation)
# Saved original image: Amanita_caesarea15.png (without annotation)
# Processed and saved: Amanita_caesarea16.png (with annotation)
# Saved original image: Amanita_caesarea17.png (without annotation)
# Processed and saved: Amanita_caesarea18.png (with annotation)
# Processed and saved: Amanita_caesarea19.png (with annotation)
# Processed and saved: Amanita_caesarea20.png (with annotation)
# Processed and saved: Amanita_caesarea21.png (with annotation)
# Processed and saved: Amanita_caesarea22.png (with annotation)
# Processed and saved: Amanita_caesarea23.png (with annotation)
# Processed and saved: Amanita_fulva0.png (with annotation)
# Processed and saved: Amanita_fulva1.png (with annotation)
# Processed and saved: Amanita_fulva10.png (with annotation)
# Processed and saved: Amanita_fulva11.png (with annotation)
# Processed and saved: Amanita_fulva12.png (with annotation)
# Processed and saved: Amanita_fulva13.png (with annotation)
# Processed and saved: Amanita_fulva14.png (with annotation)
# Processed and saved: Amanita_fulva15.png (with annotation)
# Processed and saved: Amanita_fulva16.png (with annotation)
# Processed and saved: Amanita_fulva17.png (with annotation)
# Processed and saved: Amanita_fulva18.png (with annotation)
# Processed and saved: Amanita_fulva19.png (with annotation)
# Processed and saved: Amanita_fulva2.png (with annotation)
# Processed and saved: Amanita_fulva20.png (with annotation)
# Processed and saved: Amanita_fulva21.png (with annotation)
# Processed and saved: Amanita_fulva22.png (with annotation)
# Processed and saved: Amanita_fulva23.png (with annotation)
# Processed and saved: Amanita_fulva24.png (with annotation)
# Processed and saved: Amanita_fulva25.png (with annotation)
# Saved original image: Amanita_fulva26.png (without annotation)
# Processed and saved: Amanita_fulva27.png (with annotation)
# Processed and saved: Amanita_fulva28.png (with annotation)
# Processed and saved: Amanita_fulva29.png (with annotation)
# Processed and saved: Amanita_fulva3.png (with annotation)
# Processed and saved: Amanita_fulva30.png (with annotation)
# Processed and saved: Amanita_fulva31.png (with annotation)
# Processed and saved: Amanita_fulva32.png (with annotation)
# Processed and saved: Amanita_fulva33.png (with annotation)
# Processed and saved: Amanita_fulva34.png (with annotation)
# Processed and saved: Amanita_fulva35.png (with annotation)
# Processed and saved: Amanita_fulva36.png (with annotation)
# Processed and saved: Amanita_fulva37.png (with annotation)
# Processed and saved: Amanita_fulva38.png (with annotation)
# Processed and saved: Amanita_fulva39.png (with annotation)
# Processed and saved: Amanita_fulva4.png (with annotation)
# Processed and saved: Amanita_fulva40.png (with annotation)
# Processed and saved: Amanita_fulva41.png (with annotation)
# Processed and saved: Amanita_fulva42.png (with annotation)
# Processed and saved: Amanita_fulva43.png (with annotation)
# Processed and saved: Amanita_fulva44.png (with annotation)
# Processed and saved: Amanita_fulva45.png (with annotation)
# Processed and saved: Amanita_fulva46.png (with annotation)
# Processed and saved: Amanita_fulva47.png (with annotation)
# Processed and saved: Amanita_fulva48.png (with annotation)
# Processed and saved: Amanita_fulva49.png (with annotation)
# Processed and saved: Amanita_fulva5.png (with annotation)
# Processed and saved: Amanita_fulva50.png (with annotation)
# Processed and saved: Amanita_fulva6.png (with annotation)
# Processed and saved: Amanita_fulva7.png (with annotation)
# Processed and saved: Amanita_fulva8.png (with annotation)
# Processed and saved: Amanita_fulva9.png (with annotation)
# Processed and saved: Amanita_muscaria10.png (with annotation)
# Processed and saved: Amanita_muscaria12.png (with annotation)
# Processed and saved: Amanita_muscaria13.png (with annotation)
# Processed and saved: Amanita_muscaria15.png (with annotation)
# Processed and saved: Amanita_muscaria17.png (with annotation)
# Processed and saved: Amanita_muscaria18.png (with annotation)
# Processed and saved: Amanita_muscaria2.png (with annotation)
# Saved original image: Amanita_muscaria20.png (without annotation)
# Processed and saved: Amanita_muscaria22.png (with annotation)
# Processed and saved: Amanita_muscaria23.png (with annotation)
# Processed and saved: Amanita_muscaria25.png (with annotation)
# Processed and saved: Amanita_muscaria28.png (with annotation)
# Processed and saved: Amanita_muscaria3.png (with annotation)
# Processed and saved: Amanita_muscaria30.png (with annotation)
# Processed and saved: Amanita_muscaria31.png (with annotation)
# Processed and saved: Amanita_muscaria32.png (with annotation)
# Processed and saved: Amanita_muscaria33.png (with annotation)
# Processed and saved: Amanita_muscaria34.png (with annotation)
# Processed and saved: Amanita_muscaria35.png (with annotation)
# Processed and saved: Amanita_muscaria37.png (with annotation)
# Processed and saved: Amanita_muscaria38.png (with annotation)
# Processed and saved: Amanita_muscaria39.png (with annotation)
# Processed and saved: Amanita_muscaria4.png (with annotation)
# Processed and saved: Amanita_muscaria40.png (with annotation)
# Processed and saved: Amanita_muscaria41.png (with annotation)
# Processed and saved: Amanita_muscaria43.png (with annotation)
# Processed and saved: Amanita_muscaria44.png (with annotation)
# Processed and saved: Amanita_muscaria49.png (with annotation)
# Saved original image: Amanita_muscaria5.png (without annotation)
# Processed and saved: Amanita_muscaria51.png (with annotation)
# Processed and saved: Amanita_muscaria52.png (with annotation)
# Processed and saved: Amanita_muscaria53.png (with annotation)
# Processed and saved: Amanita_muscaria54.png (with annotation)
# Processed and saved: Amanita_muscaria57.png (with annotation)
# Processed and saved: Amanita_muscaria58.png (with annotation)
# Processed and saved: Amanita_muscaria59.png (with annotation)
# Processed and saved: Amanita_muscaria6.png (with annotation)
# Processed and saved: Amanita_muscaria60.png (with annotation)
# Processed and saved: Amanita_muscaria61.png (with annotation)
# Processed and saved: Amanita_muscaria62.png (with annotation)
# Processed and saved: Amanita_muscaria63.png (with annotation)
# Processed and saved: Amanita_muscaria64.png (with annotation)
# Processed and saved: Amanita_muscaria65.png (with annotation)
# Processed and saved: Amanita_muscaria66.png (with annotation)
# Processed and saved: Amanita_muscaria67.png (with annotation)
# Processed and saved: Amanita_muscaria68.png (with annotation)
# Processed and saved: Amanita_muscaria69.png (with annotation)
# Saved original image: Amanita_muscaria7.png (without annotation)
# Processed and saved: Amanita_muscaria70.png (with annotation)
# Processed and saved: Amanita_muscaria71.png (with annotation)
# Processed and saved: Amanita_muscaria8.png (with annotation)
# Processed and saved: Amanita_rubescens0.png (with annotation)
# Processed and saved: Amanita_rubescens1.png (with annotation)
# Processed and saved: Amanita_rubescens10.png (with annotation)
# Processed and saved: Amanita_rubescens11.png (with annotation)
# Processed and saved: Amanita_rubescens12.png (with annotation)
# Processed and saved: Amanita_rubescens13.png (with annotation)
# Processed and saved: Amanita_rubescens14.png (with annotation)
# Processed and saved: Amanita_rubescens15.png (with annotation)
# Processed and saved: Amanita_rubescens16.png (with annotation)
# Processed and saved: Amanita_rubescens17.png (with annotation)
# Processed and saved: Amanita_rubescens19.png (with annotation)
# Processed and saved: Amanita_rubescens2.png (with annotation)
# Processed and saved: Amanita_rubescens20.png (with annotation)
# Processed and saved: Amanita_rubescens21.png (with annotation)
# Processed and saved: Amanita_rubescens22.png (with annotation)
# Processed and saved: Amanita_rubescens23.png (with annotation)
# Processed and saved: Amanita_rubescens24.png (with annotation)
# Processed and saved: Amanita_rubescens25.png (with annotation)
# Processed and saved: Amanita_rubescens26.png (with annotation)
# Processed and saved: Amanita_rubescens27.png (with annotation)
# Processed and saved: Amanita_rubescens29.png (with annotation)
# Processed and saved: Amanita_rubescens3.png (with annotation)
# Processed and saved: Amanita_rubescens30.png (with annotation)
# Processed and saved: Amanita_rubescens31.png (with annotation)
# Processed and saved: Amanita_rubescens32.png (with annotation)
# Processed and saved: Amanita_rubescens33.png (with annotation)
# Processed and saved: Amanita_rubescens34.png (with annotation)
# Processed and saved: Amanita_rubescens35.png (with annotation)
# Processed and saved: Amanita_rubescens36.png (with annotation)
# Processed and saved: Amanita_rubescens37.png (with annotation)
# Processed and saved: Amanita_rubescens38.png (with annotation)
# Processed and saved: Amanita_rubescens39.png (with annotation)
# Processed and saved: Amanita_rubescens40.png (with annotation)
# Processed and saved: Amanita_rubescens41.png (with annotation)
# Processed and saved: Amanita_rubescens42.png (with annotation)
# Processed and saved: Amanita_rubescens43.png (with annotation)
# Processed and saved: Amanita_rubescens44.png (with annotation)
# Processed and saved: Amanita_rubescens45.png (with annotation)
# Processed and saved: Amanita_rubescens46.png (with annotation)
# Processed and saved: Amanita_rubescens48.png (with annotation)
# Processed and saved: Amanita_rubescens49.png (with annotation)
# Processed and saved: Amanita_rubescens5.png (with annotation)
# Processed and saved: Amanita_rubescens50.png (with annotation)
# Processed and saved: Amanita_rubescens51.png (with annotation)
# Processed and saved: Amanita_rubescens52.png (with annotation)
# Processed and saved: Amanita_rubescens53.png (with annotation)
# Processed and saved: Amanita_rubescens55.png (with annotation)
# Processed and saved: Amanita_rubescens56.png (with annotation)
# Processed and saved: Amanita_rubescens57.png (with annotation)
# Processed and saved: Amanita_rubescens58.png (with annotation)
# Processed and saved: Amanita_rubescens59.png (with annotation)
# Processed and saved: Amanita_rubescens6.png (with annotation)
# Processed and saved: Amanita_rubescens60.png (with annotation)
# Processed and saved: Amanita_rubescens61.png (with annotation)
# Processed and saved: Amanita_rubescens62.png (with annotation)
# Processed and saved: Amanita_rubescens7.png (with annotation)
# Processed and saved: Amanita_rubescens8.png (with annotation)
# Saved original image: Amanita_rubescens9.png (without annotation)
# Processed and saved: Coprinopsis_atramentaria0.png (with annotation)
# Processed and saved: Coprinopsis_atramentaria1.png (with annotation)
# Saved original image: Coprinopsis_atramentaria10.png (without annotation)
# Saved original image: Coprinopsis_atramentaria11.png (without annotation)
# Processed and saved: Coprinopsis_atramentaria13.png (with annotation)
# Processed and saved: Coprinopsis_atramentaria14.png (with annotation)
# Processed and saved: Coprinopsis_atramentaria15.png (with annotation)
# Saved original image: Coprinopsis_atramentaria16.png (without annotation)
# Saved original image: Coprinopsis_atramentaria17.png (without annotation)
# Processed and saved: Coprinopsis_atramentaria18.png (with annotation)
# Processed and saved: Coprinopsis_atramentaria19.png (with annotation)
# Saved original image: Coprinopsis_atramentaria2.png (without annotation)
# Processed and saved: Coprinopsis_atramentaria20.png (with annotation)
# Processed and saved: Coprinopsis_atramentaria21.png (with annotation)
# Processed and saved: Coprinopsis_atramentaria22.png (with annotation)
# Processed and saved: Coprinopsis_atramentaria23.png (with annotation)
# Processed and saved: Coprinopsis_atramentaria24.png (with annotation)
# Processed and saved: Coprinopsis_atramentaria25.png (with annotation)
# Processed and saved: Coprinopsis_atramentaria26.png (with annotation)
# Processed and saved: Coprinopsis_atramentaria27.png (with annotation)
# Processed and saved: Coprinopsis_atramentaria28.png (with annotation)
# Processed and saved: Coprinopsis_atramentaria29.png (with annotation)
# Processed and saved: Coprinopsis_atramentaria3.png (with annotation)
# Processed and saved: Coprinopsis_atramentaria30.png (with annotation)
# Processed and saved: Coprinopsis_atramentaria31.png (with annotation)
# Processed and saved: Coprinopsis_atramentaria32.png (with annotation)
# Processed and saved: Coprinopsis_atramentaria33.png (with annotation)
# Processed and saved: Coprinopsis_atramentaria34.png (with annotation)
# Processed and saved: Coprinopsis_atramentaria35.png (with annotation)
# Processed and saved: Coprinopsis_atramentaria36.png (with annotation)
# Processed and saved: Coprinopsis_atramentaria37.png (with annotation)
# Processed and saved: Coprinopsis_atramentaria38.png (with annotation)
# Processed and saved: Coprinopsis_atramentaria39.png (with annotation)
# Processed and saved: Coprinopsis_atramentaria40.png (with annotation)
# Processed and saved: Coprinopsis_atramentaria42.png (with annotation)
# Processed and saved: Coprinopsis_atramentaria43.png (with annotation)
# Processed and saved: Coprinopsis_atramentaria44.png (with annotation)
# Processed and saved: Coprinopsis_atramentaria45.png (with annotation)
# Processed and saved: Coprinopsis_atramentaria46.png (with annotation)
# Processed and saved: Coprinopsis_atramentaria47.png (with annotation)
# Processed and saved: Coprinopsis_atramentaria48.png (with annotation)
# Processed and saved: Coprinopsis_atramentaria49.png (with annotation)
# Processed and saved: Coprinopsis_atramentaria5.png (with annotation)
# Processed and saved: Coprinopsis_atramentaria50.png (with annotation)
# Saved original image: Coprinopsis_atramentaria51.png (without annotation)
# Processed and saved: Coprinopsis_atramentaria52.png (with annotation)
# Processed and saved: Coprinopsis_atramentaria53.png (with annotation)
# Processed and saved: Coprinopsis_atramentaria54.png (with annotation)
# Processed and saved: Coprinopsis_atramentaria55.png (with annotation)
# Processed and saved: Coprinopsis_atramentaria56.png (with annotation)
# Processed and saved: Coprinopsis_atramentaria57.png (with annotation)
# Processed and saved: Coprinopsis_atramentaria58.png (with annotation)
# Processed and saved: Coprinopsis_atramentaria6.png (with annotation)
# Processed and saved: Coprinopsis_atramentaria7.png (with annotation)
# Processed and saved: Coprinopsis_atramentaria8.png (with annotation)
# Processed and saved: Coprinopsis_atramentaria9.png (with annotation)
# Processed and saved: Gyromitra_esculenta0.png (with annotation)
# Processed and saved: Gyromitra_esculenta1.png (with annotation)
# Processed and saved: Gyromitra_esculenta10.png (with annotation)
# Processed and saved: Gyromitra_esculenta14.png (with annotation)
# Processed and saved: Gyromitra_esculenta15.png (with annotation)
# Processed and saved: Gyromitra_esculenta17.png (with annotation)
# Processed and saved: Gyromitra_esculenta18.png (with annotation)
# Processed and saved: Gyromitra_esculenta19.png (with annotation)
# Processed and saved: Gyromitra_esculenta2.png (with annotation)
# Processed and saved: Gyromitra_esculenta20.png (with annotation)
# Processed and saved: Gyromitra_esculenta21.png (with annotation)
# Processed and saved: Gyromitra_esculenta22.png (with annotation)
# Processed and saved: Gyromitra_esculenta23.png (with annotation)
# Processed and saved: Gyromitra_esculenta24.png (with annotation)
# Processed and saved: Gyromitra_esculenta26.png (with annotation)
# Processed and saved: Gyromitra_esculenta29.png (with annotation)
# Processed and saved: Gyromitra_esculenta30.png (with annotation)
# Processed and saved: Gyromitra_esculenta31.png (with annotation)
# Processed and saved: Gyromitra_esculenta32.png (with annotation)
# Processed and saved: Gyromitra_esculenta33.png (with annotation)
# Processed and saved: Gyromitra_esculenta34.png (with annotation)
# Processed and saved: Gyromitra_esculenta36.png (with annotation)
# Processed and saved: Gyromitra_esculenta37.png (with annotation)
# Processed and saved: Gyromitra_esculenta38.png (with annotation)
# Processed and saved: Gyromitra_esculenta39.png (with annotation)
# Processed and saved: Gyromitra_esculenta4.png (with annotation)
# Processed and saved: Gyromitra_esculenta41.png (with annotation)
# Processed and saved: Gyromitra_esculenta42.png (with annotation)
# Processed and saved: Gyromitra_esculenta43.png (with annotation)
# Processed and saved: Gyromitra_esculenta44.png (with annotation)
# Processed and saved: Gyromitra_esculenta46.png (with annotation)
# Processed and saved: Gyromitra_esculenta47.png (with annotation)
# Processed and saved: Gyromitra_esculenta48.png (with annotation)
# Processed and saved: Gyromitra_esculenta5.png (with annotation)
# Processed and saved: Gyromitra_esculenta50.png (with annotation)
# Processed and saved: Gyromitra_esculenta51.png (with annotation)
# Processed and saved: Gyromitra_esculenta52.png (with annotation)
# Processed and saved: Gyromitra_esculenta53.png (with annotation)
# Processed and saved: Gyromitra_esculenta54.png (with annotation)
# Processed and saved: Gyromitra_esculenta55.png (with annotation)
# Processed and saved: Gyromitra_esculenta56.png (with annotation)
# Processed and saved: Gyromitra_esculenta6.png (with annotation)
# Processed and saved: Gyromitra_esculenta8.png (with annotation)
# Processed and saved: Gyromitra_esculenta9.png (with annotation)
# Processed and saved: Lepista_saeva0.png (with annotation)
# Processed and saved: Lepista_saeva1.png (with annotation)
# Processed and saved: Lepista_saeva10.png (with annotation)
# Processed and saved: Lepista_saeva11.png (with annotation)
# Processed and saved: Lepista_saeva12.png (with annotation)
# Processed and saved: Lepista_saeva13.png (with annotation)
# Processed and saved: Lepista_saeva14.png (with annotation)
# Processed and saved: Lepista_saeva15.png (with annotation)
# Processed and saved: Lepista_saeva16.png (with annotation)
# Processed and saved: Lepista_saeva17.png (with annotation)
# Processed and saved: Lepista_saeva18.png (with annotation)
# Processed and saved: Lepista_saeva19.png (with annotation)
# Processed and saved: Lepista_saeva2.png (with annotation)
# Processed and saved: Lepista_saeva20.png (with annotation)
# Processed and saved: Lepista_saeva21.png (with annotation)
# Processed and saved: Lepista_saeva22.png (with annotation)
# Processed and saved: Lepista_saeva23.png (with annotation)
# Processed and saved: Lepista_saeva24.png (with annotation)
# Processed and saved: Lepista_saeva25.png (with annotation)
# Processed and saved: Lepista_saeva26.png (with annotation)
# Processed and saved: Lepista_saeva27.png (with annotation)
# Processed and saved: Lepista_saeva28.png (with annotation)
# Processed and saved: Lepista_saeva29.png (with annotation)
# Processed and saved: Lepista_saeva3.png (with annotation)
# Processed and saved: Lepista_saeva30.png (with annotation)
# Processed and saved: Lepista_saeva31.png (with annotation)
# Processed and saved: Lepista_saeva32.png (with annotation)
# Processed and saved: Lepista_saeva33.png (with annotation)
# Processed and saved: Lepista_saeva34.png (with annotation)
# Processed and saved: Lepista_saeva35.png (with annotation)
# Processed and saved: Lepista_saeva36.png (with annotation)
# Processed and saved: Lepista_saeva37.png (with annotation)
# Processed and saved: Lepista_saeva38.png (with annotation)
# Processed and saved: Lepista_saeva39.png (with annotation)
# Processed and saved: Lepista_saeva4.png (with annotation)
# Processed and saved: Lepista_saeva40.png (with annotation)
# Processed and saved: Lepista_saeva41.png (with annotation)
# Processed and saved: Lepista_saeva42.png (with annotation)
# Processed and saved: Lepista_saeva45.png (with annotation)
# Processed and saved: Lepista_saeva46.png (with annotation)
# Processed and saved: Lepista_saeva47.png (with annotation)
# Processed and saved: Lepista_saeva48.png (with annotation)
# Processed and saved: Lepista_saeva49.png (with annotation)
# Processed and saved: Lepista_saeva5.png (with annotation)
# Processed and saved: Lepista_saeva50.png (with annotation)
# Processed and saved: Lepista_saeva51.png (with annotation)
# Processed and saved: Lepista_saeva52.png (with annotation)
# Processed and saved: Lepista_saeva53.png (with annotation)
# Processed and saved: Lepista_saeva54.png (with annotation)
# Processed and saved: Lepista_saeva6.png (with annotation)
# Processed and saved: Lepista_saeva7.png (with annotation)
# Processed and saved: Lepista_saeva8.png (with annotation)
# Processed and saved: Lepista_saeva9.png (with annotation)
# Processed and saved: Morchella_esculenta1.png (with annotation)
# Processed and saved: Morchella_esculenta10.png (with annotation)
# Processed and saved: Morchella_esculenta12.png (with annotation)
# Processed and saved: Morchella_esculenta16.png (with annotation)
# Processed and saved: Morchella_esculenta17.png (with annotation)
# Processed and saved: Morchella_esculenta18.png (with annotation)
# Processed and saved: Morchella_esculenta19.png (with annotation)
# Processed and saved: Morchella_esculenta2.png (with annotation)
# Processed and saved: Morchella_esculenta20.png (with annotation)
# Saved original image: Morchella_esculenta21.png (without annotation)
# Processed and saved: Morchella_esculenta23.png (with annotation)
# Processed and saved: Morchella_esculenta25.png (with annotation)
# Saved original image: Morchella_esculenta26.png (without annotation)
# Processed and saved: Morchella_esculenta27.png (with annotation)
# Saved original image: Morchella_esculenta28.png (without annotation)
# Processed and saved: Morchella_esculenta29.png (with annotation)
# Processed and saved: Morchella_esculenta30.png (with annotation)
# Processed and saved: Morchella_esculenta31.png (with annotation)
# Processed and saved: Morchella_esculenta32.png (with annotation)
# Processed and saved: Morchella_esculenta33.png (with annotation)
# Processed and saved: Morchella_esculenta34.png (with annotation)
# Processed and saved: Morchella_esculenta35.png (with annotation)
# Processed and saved: Morchella_esculenta36.png (with annotation)
# Processed and saved: Morchella_esculenta37.png (with annotation)
# Processed and saved: Morchella_esculenta38.png (with annotation)
# Processed and saved: Morchella_esculenta39.png (with annotation)
# Processed and saved: Morchella_esculenta40.png (with annotation)
# Processed and saved: Morchella_esculenta41.png (with annotation)
# Processed and saved: Morchella_esculenta42.png (with annotation)
# Processed and saved: Morchella_esculenta43.png (with annotation)
# Processed and saved: Morchella_esculenta44.png (with annotation)
# Processed and saved: Morchella_esculenta45.png (with annotation)
# Processed and saved: Morchella_esculenta47.png (with annotation)
# Processed and saved: Morchella_esculenta48.png (with annotation)
# Processed and saved: Morchella_esculenta49.png (with annotation)
# Processed and saved: Morchella_esculenta50.png (with annotation)
# Processed and saved: Morchella_esculenta51.png (with annotation)
# Processed and saved: Morchella_esculenta52.png (with annotation)
# Processed and saved: Morchella_esculenta53.png (with annotation)
# Saved original image: Morchella_esculenta54.png (without annotation)
# Processed and saved: Morchella_esculenta56.png (with annotation)
# Processed and saved: Morchella_esculenta57.png (with annotation)
# Processed and saved: Morchella_esculenta58.png (with annotation)
# Processed and saved: Morchella_esculenta59.png (with annotation)
# Processed and saved: Morchella_esculenta60.png (with annotation)
# Processed and saved: Morchella_esculenta61.png (with annotation)
# Processed and saved: Morchella_esculenta62.png (with annotation)
# Processed and saved: Morchella_esculenta63.png (with annotation)
# Processed and saved: Morchella_esculenta64.png (with annotation)
# Processed and saved: Morchella_esculenta65.png (with annotation)
# Processed and saved: Morchella_esculenta66.png (with annotation)
# Processed and saved: Morchella_esculenta67.png (with annotation)
# Processed and saved: Morchella_esculenta68.png (with annotation)
# Processed and saved: Morchella_esculenta69.png (with annotation)
# Processed and saved: Morchella_esculenta70.png (with annotation)
# Processed and saved: Morchella_esculenta71.png (with annotation)
# Saved original image: Morchella_esculenta8.png (without annotation)
# Processed and saved: Morchella_esculenta9.png (with annotation)
# Processed and saved: Verpa_bohemica0.png (with annotation)
# Processed and saved: Verpa_bohemica1.png (with annotation)
# Processed and saved: Verpa_bohemica10.png (with annotation)
# Processed and saved: Verpa_bohemica11.png (with annotation)
# Processed and saved: Verpa_bohemica12.png (with annotation)
# Processed and saved: Verpa_bohemica13.png (with annotation)
# Processed and saved: Verpa_bohemica14.png (with annotation)
# Processed and saved: Verpa_bohemica15.png (with annotation)
# Processed and saved: Verpa_bohemica16.png (with annotation)
# Processed and saved: Verpa_bohemica17.png (with annotation)
# Processed and saved: Verpa_bohemica18.png (with annotation)
# Processed and saved: Verpa_bohemica19.png (with annotation)
# Processed and saved: Verpa_bohemica2.png (with annotation)
# Processed and saved: Verpa_bohemica20.png (with annotation)
# Processed and saved: Verpa_bohemica21.png (with annotation)
# Processed and saved: Verpa_bohemica22.png (with annotation)
# Processed and saved: Verpa_bohemica24.png (with annotation)
# Processed and saved: Verpa_bohemica25.png (with annotation)
# Processed and saved: Verpa_bohemica26.png (with annotation)
# Processed and saved: Verpa_bohemica27.png (with annotation)
# Processed and saved: Verpa_bohemica28.png (with annotation)
# Processed and saved: Verpa_bohemica29.png (with annotation)
# Saved original image: Verpa_bohemica3.png (without annotation)
# Processed and saved: Verpa_bohemica30.png (with annotation)
# Processed and saved: Verpa_bohemica31.png (with annotation)
# Processed and saved: Verpa_bohemica32.png (with annotation)
# Processed and saved: Verpa_bohemica33.png (with annotation)
# Processed and saved: Verpa_bohemica34.png (with annotation)
# Processed and saved: Verpa_bohemica35.png (with annotation)
# Processed and saved: Verpa_bohemica37.png (with annotation)
# Processed and saved: Verpa_bohemica39.png (with annotation)
# Processed and saved: Verpa_bohemica4.png (with annotation)
# Processed and saved: Verpa_bohemica40.png (with annotation)
# Processed and saved: Verpa_bohemica41.png (with annotation)
# Processed and saved: Verpa_bohemica42.png (with annotation)
# Processed and saved: Verpa_bohemica43.png (with annotation)
# Processed and saved: Verpa_bohemica44.png (with annotation)
# Processed and saved: Verpa_bohemica45.png (with annotation)
# Processed and saved: Verpa_bohemica46.png (with annotation)
# Processed and saved: Verpa_bohemica47.png (with annotation)
# Processed and saved: Verpa_bohemica49.png (with annotation)
# Processed and saved: Verpa_bohemica5.png (with annotation)
# Processed and saved: Verpa_bohemica50.png (with annotation)
# Processed and saved: Verpa_bohemica51.png (with annotation)
# Processed and saved: Verpa_bohemica52.png (with annotation)
# Processed and saved: Verpa_bohemica6.png (with annotation)
# Saved original image: Verpa_bohemica7.png (without annotation)
# Processed and saved: Verpa_bohemica8.png (with annotation)
# Processed and saved: Verpa_bohemica9.png (with annotation)
